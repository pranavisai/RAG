# %%
from langchain_core.documents import Document

# %%
doc = Document(page_content="This is a test document.", metadata={"source": "test_source"})
doc
# Out:
# Document(metadata={'source': 'test_source'}, page_content='This is a test document.')

# %%
import os

# %%
os.makedirs("../data/text_files", exist_ok=True)

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python\n\nPython is a versatile, high-level programming language created by Guido\nvan Rossum and first released in 1991. It was designed with an emphasis\non readability and developer productivity, making it one of the most\npopular programming languages in the world.\n\nWhy Python is Popular\n\nPython uses a clean and simple syntax that allows developers to focus on\nsolving problems rather than dealing with complex language rules.\nBecause of this, Python is often recommended as a first programming\nlanguage for beginners.\n\nAdvantages include: - Easy to learn and read - Large ecosystem of\nlibraries and frameworks - Cross-platform compatibility - Strong\ncommunity support - Rapid application development\n\nCommon Applications\n\nWeb Development\n\nPython is widely used for building websites and web applications.\nPopular frameworks include: - Django - Flask - FastAPI\n\nData Analysis\n\nPython ha
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader

## load all text files from the directory
dir_loader = DirectoryLoader("../data/text_files", 
                             glob="*.txt",  ## pattern to match files
                             loader_cls=TextLoader,  ## specify the loader class to use for each file (currently all text files and hence text loader)
                             loader_kwargs={"encoding": "utf-8"},  ## kwargs to pass to the loader class
                             show_progress=False)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python\n\nPython is a versatile, high-level programming language created by Guido\nvan Rossum and first released in 1991. It was designed with an emphasis\non readability and developer productivity, making it one of the most\npopular programming languages in the world.\n\nWhy Python is Popular\n\nPython uses a clean and simple syntax that allows developers to focus on\nsolving problems rather than dealing with complex language rules.\nBecause of this, Python is often recommended as a first programming\nlanguage for beginners.\n\nAdvantages include: - Easy to learn and read - Large ecosystem of\nlibraries and frameworks - Cross-platform compatibility - Strong\ncommunity support - Rapid application development\n\nCommon Applications\n\nWeb Development\n\nPython is widely used for building websites and web applications.\nPopular frameworks include: - Django - Flask - FastAPI\n\nData Analysis\n\nPython ha
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
dir_loader = DirectoryLoader("../data/pdf", 
                             glob="*.pdf",  ## pattern to match files
                             loader_cls=PyMuPDFLoader,  ## specify the loader class to use for each file (currently all text files and hence text loader)
                             show_progress=False)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m150 Google Docs Renderer', 'creator': '', 'creationdate': '', 'source': '../data/pdf/data_engineer_thryve_Cover_letter.pdf', 'file_path': '../data/pdf/data_engineer_thryve_Cover_letter.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'data_engineer_thryve_Cover_letter', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Dear Kyla Rushidi, \nI hope you are doing well. \nI am writing to apply for the Data Engineer position. To make it easier to read, my cover letter is \nsplit into three parts, a brief overview of why I am looking for a new position, what my strengths \nare, and how my skills fit this position. \nMost recently, I worked at Morpheus Space, where I co-led the development and stabilization of \nproduction software in the aerospace sector. Prior to that, I developed data-driven applications, \nETL pipelines, automation solutions, and backend 
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
